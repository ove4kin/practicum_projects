# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера</h1>
#
# Привет, Дмитрий!
#
# Меня зовут Николай Акопджанов, и я буду проверять твой проект) Предлагаю нам сразу перейти на ты, если ты не против)
#
# Стоит сразу заметить, что основная моя задача помочь тебе в освоении пройденного материала, а не в оценке проекта.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> и есть такой 👍 знак  - всё сделано правильно; <font color=orange>оранжевый</font> и есть такой 💡 знак - есть что улучшить, но не критично; <font color=red>красный</font> и есть такой ❌ знак- нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
#
# Ты можешь отвечать мне своими комментариями и выделять их другим <font color=blue>цветом</font>.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера</h1>
#
#
# Еще раз привет!
#
# Спасибо за доработку проекта.
# Новые комментарии будут отмечены V2
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd # Импортируем библиотеку pandas и присваиваем ей псевдоним pd

df = pd.read_csv('/datasets/real_estate_data.csv') # Считываем таблицу в переменную df

df.head() # Оцениваем первые строки таблицы. Необходимо использовать разделитель '\t' при считывании
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') # Считываем таблицу в переменную df с разделителем

df.head() # Теперь, когда добавлен аргумент sep в метод read_csv(), таблица стала читабельной
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Таблица была считана, при считывании нам потребовалось использовать разделитель '\t', чтобы данные отображались корректно. Мы оценили первые 5 записей и уже по ним поняли, что данные нуждаются в предобработке: таблица имеет пропуски и некорректные значения, например в столбце first_day_exposition даты отображены неверно. Исправим это в следующих шагах

# %% [markdown]
# ## Предобработка данных

# %%
len(df) # Узнаем количество записей в таблице
# Out:
# 23699

# %%
df.duplicated().sum() # Выясним, содержит ли таблица явные дубликаты. Не содержит
# Out:
# 0

# %%
df.info() # Изучим общую информацию о данных, обратим внимание на их типы и имена.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# Приведём имена столбцов 'cityCenters_nearest', 'parks_around3000', 'ponds_around3000' к снэйккейсу.

df = df.rename(columns={
    'cityCenters_nearest': 'city_centers_nearest',
    'parks_around3000': 'parks_around_3000',
    'ponds_around3000': 'ponds_around_3000'
})

df.columns # Убедимся, что имена столбцов поменялись
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Молодец, так будет удобнее читать)
# </div>

# %% [markdown]
# Обратим внимание на то, что столбец first_day_exposition имеет тип object, хотя содержит информацию о дате, столбец floors_total имеет тип float, хотя количество этажей в доме не может быть числом с плавающей точкой, столбец is_apartment имеет тип object, но по названию столбцу больше подошёл бы тип bool, balcony так же имеет тип float, но число балконов может быть только целым числом. Столбец days_expostion также имеет тип float, но количетсво дней привычнее считать целым числом.

# %%
df.isna().sum() # Оценим количество пропусков в столбцах таблицы.
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Основываясь на данных о количестве пропусков, можно предположить, что пропуски в столбцах city_centers_nearest, parks_around_3000 и ponds_around_3000 имеют единую природу происхождения: скорее всего, они пришли в таблицу из одного источника, в котором не было данных о ближайших парках, водоёмах и расстоянии до центра от объекта недвижимости.
#
# На пропуски в каких столбцах мы точно можем повлиять:
#
# balcony — скорее всего, если данных о балконах нет, то нет и балконов.
# flors_total — данных с пропусками не так много, можно их удалить: это ни на что не повлияет.
# is_apartment — мы уже предположили, что этому столбцу подошёл бы тип данных bool, а это значит, что вариантов заполнения этого столбца у нас два: True и False. Необходимо установить критерии, в соответствии с которыми там, где это возможно, будем заменять пропуски на True или False.
# living_area — площадь квартиры зависит как от количества комнат, так и от серии дома. Пропусков в столбце rooms у нас нет и это могло бы помочь, например, при рассчёте медианного значения площади квартиры, но мы не обладаем данными о серии дома, поэтому предстоить сделать выбор: избавиться ли от строк с пропусками в столбце living_area (а таких строк не мало) или заполнить их медианой.
# locality_name — таких пропусков 49, можем избавиться от строк с ними, их удаление не повлияет на общую картину.
# first_day_exposition — приведём к типу datetime.
# days_exposition — этот столбец содержит значения дней, которое объявление провело будучи активным. Поскольку в другом столбце с датой first_day_exposition у нас нет пропусков, можно предположить, что объявления с пропусками в столбце days_exposition до сих пор активны, а значит мы можем посчитать число дней, которое прошло с момента публикации до сегодняшнего дня, чтобы получить корректные данные в этом столбце вместо пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Очень все логично, молодец)
# </div>

# %%
df = df.dropna(subset=['locality_name']) # Удалим строки с пропусками в столбце 'locality_name'
df['locality_name'].isna().sum() # Убедимся, что пропусков не осталось
# Out:
# 0

# %%
df['balcony'] = df['balcony'].fillna(0) # Заменили пропуски в столбце 'balcony' на 0.
df['balcony'] = df['balcony'].astype('int') # Привели значения столбца 'balcony' к типу 'int'.

df['balcony'].value_counts() # Оценили значения в обновлённом столбце 'balcony'.
# Out:
# 0    15238
# 1     4187
# 2     3658
# 5      304
# 4      182
# 3       81
# Name: balcony, dtype: int64

# %%
df['is_apartment'].value_counts() # Ознакомимся со значениями столбца 'is_apartment'
# Out:
# False    2710
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Значений False в столбце 'is_apartment' 2710, True — 50. Остальные значения (20924) — пропуски. Их большинство. Зная о том, что аппартаменты в среднем дешевле, чем жилая площадь, а также зная, что на цену недвижимости влияет её удалённость от центра, можно категоризировать объекты по удалённости от центра (сделаем это для объектов в Санкт-Петербурге), также не будем забывать о том, что объекты недвижимости имеют разное число комнат, что так же оказывает влияние на цену. Выберем самые популярные предложения по числу комнат, разделим предложения на группы по удалённости от центра и для каждого сегмента посчитаем значение разности медианы и полутора межквартильных размахов в столбце со стоимостью. Объекты, чьи цены окажутся ниже этого значения будем считать аппартаментами.

# %%
# Сохраним в отдельной переменной df_apartment_false таблицу со значениями False в столбце 'is_apartment'
# Она потребуется нам для рассчёта медианных значений стоимости объектов недвижимости.

df_apartment_false = df.query('is_apartment == False')
df_apartment_false.shape # Таблица со значениями False в столбце 'is_apartment' создана и содержит 2725 записей
# Out:
# (2710, 22)

# %%
# Посмотрим на то, какими населёнными пунктами представлен столбец 'locality_name' таблицы df_apartment_false

df_apartment_false['locality_name'].value_counts()
# Out:
# Санкт-Петербург                        1794
# посёлок Шушары                           58
# посёлок Мурино                           54
# деревня Кудрово                          48
# Пушкин                                   48
#                                        ...
# село Павлово                              1
# поселок городского типа Кондратьево       1
# поселок Громово                           1
# поселок Гарболово                         1
# поселок Лисий Нос                         1
# Name: locality_name, Length: 139, dtype: int64

# %% [markdown]
# Лидер по количеству предложений объектов недвижимости — Санкт-Петербург, чего и следовало ожидать. Всего уникальных записей 139, а многие из городов имеют по одному объявлению с указанием типа жилплощади. Одно объявление в исследовании нам не поможет воссоздать представление о средних ценах в населённом пункте. На самом деле, не поможет и 58, если мы хотим категоризировать данные объектов недвижимости внутри этого населённого пункта, например, по количеству комнат — а для того, чтобы ответить наверняка, является ли объект аппартаментами или нет, это необходимо. То есть, скорее всего, данные объектов недвижимости по Ленобласти впоследствии мы будем объединять. Сделаем это позже, пока сосредоточимся на объектах недвижимости в Санкт-Петербурге.

# %%
# Создадим отдельную переменную для значений с указаниями типа жилплощади по Санкт-Петербургу
spb_apart_false = df_apartment_false.query("locality_name == 'Санкт-Петербург'")

# Проверим, есть ли в нашей таблице пропуски в столбце 'city_centers_nearest'
spb_apart_false['city_centers_nearest'].isna().sum()
# Out:
# 5

# %%
spb_apart_false = spb_apart_false.dropna(subset=['city_centers_nearest']) # Удалим такие значения

# %%
# Убедимся, что пустые значения в столбце 'city_centers_nearest' отсутствуют
spb_apart_false['city_centers_nearest'].isna().sum()
# Out:
# 0

# %%
spb_apart_false['rooms'].value_counts() # Ознакомимся с наиболее популярными вариантами предложений
# Out:
# 2    591
# 1    554
# 3    470
# 4    123
# 5     40
# 6      5
# 7      3
# 0      2
# 9      1
# Name: rooms, dtype: int64

# %% [markdown]
# Мы видим, что наиболее популярные варианты предложений объектов недвижимости имеют 1, 2, 3 и 4 комнаты. Есть так же 40 объявлений с пятью комнатами, но, так как мы планируем категоризировать данные и по удалённости от центра в Санкт-Петербурге, 40 наблюдений будет для нас мало. Остановимся на 1-, 2-х, 3-х и 4-х комнатных предложениях.

# %%
# Создадим список, который будет содержать самые популярные значения количества комнат у объектов недвижимости
# В Санкт-Петербурге

spb_rooms = [1, 2, 3, 4]

# %%
# Разделим объекты недвижимости Санкт-Петербурга на 4 группы по удалённости от центра.
# За границы примем квартили распределения. Воспользуемся методом describe(), чтобы увидеть их.

spb_apart_false['city_centers_nearest'].describe()
# Out:
# count     1789.000000
# mean     11365.419788
# std       4783.832435
# min        208.000000
# 25%       7943.000000
# 50%      12038.000000
# 75%      14784.000000
# max      28644.000000
# Name: city_centers_nearest, dtype: float64

# %%
# Так как результатом вызова метода describe() является объект типа Series, мы можем написать функцию
# которая будет возвращать список значений квартилей из объекта Series.
def get_quartiles(column):
    first = int(column.describe()[4])
    second = int(column.describe()[5])
    third = int(column.describe()[6])
    return [first, second, third]

# %%
# Получим список значений квартилей из столбца 'city_centers_nearest'
city_centers_q = get_quartiles(spb_apart_false['city_centers_nearest'])

# %%
# Убедимся, что функция работает
print(city_centers_q)
# Out:
# [7943, 12038, 14784]

# %%
# Чтобы значениями списка city_centers_q можно было пользоваться в цикле, добавим этому списку четвёртый
# элемент, который будет соответствовать максимальному значению из столбца 'city_centers_nearest' отиндексированной 
# таблицы df, у которой значения столбца "locality_name" равны строке "Санкт-Петербург"

city_centers_q.append(int(df.query("locality_name == 'Санкт-Петербург'")['city_centers_nearest'].max()))
print(city_centers_q)
# Out:
# [7943, 12038, 14784, 29493]

# %%
# На всякий случай проверим, принимает ли столбец 'last_price' отрицательные значения. Не принимает.
df.query('last_price < 0')['last_price'].count()
# Out:
# 0

# %%
# На основе функции get_quartiles() напишем функцию, которая считает межквартильный размах
# (разницу между третьим и первым квартилем) и вычитает из значения медианы (второго квартиля)
# полтора межквартильных размаха — именно такое значение будем считать пограничным для жилой площади и 
# апартаментов

def get_minus_one_and_half_range(column):
    first_q = get_quartiles(column)[0]
    second_q = get_quartiles(column)[1]
    third_q = get_quartiles(column)[2]
    interq_range = third_q - first_q
    point = second_q - 1.5 * interq_range
    if point > 0: # Поскольку значение цены квартиры не может принимать отрицательные значения
        return point  # Функция будет возвращать значение, если оно положительное
    return 0 # В противном случае функция будет возвращать ноль.

# %%
# Теперь создадим пустой словарь, который заполним с помощью циклов for: ключами этого словаря станет 
# количество комнат в объектах недвижимости, а значениями — списки со значениями столбца 'last_price'
# равные значению, полученному в результате вычитания из медианы полутора межквартильных размахов:

# { 1-комнатные: [1-я группа, 2-я группа, 3-я группа, 4-я группа],
#   2-комнатные: [1-я группа, 2-я группа, 3-я группа, 4-я группа],
#   3-комнатные: [1-я группа, 2-я группа, 3-я группа, 4-я группа],
#   4-комнатные: [1-я группа, 2-я группа, 3-я группа, 4-я группа]
# }
# 
# Таким образом, если теперь в таблице df, отиндексированной по строкам, в которых значение столбца 
# locality_name соответствует Санкт-Петербургу, мы встретим значение цены, которое будет ниже значения первого
# квартиля для указанной группы и количества комнат, будем считать такой объект недвижимости апартаментами.
# Иначе — не будем считать такой объект недвижимости апартаментами.


quart_dict = {}

for i in spb_rooms:
    that_table = spb_apart_false[spb_apart_false['rooms'] == i]
    quart_dict[i] = []
    for j in city_centers_q:
        this_table = that_table[that_table['city_centers_nearest'] <= j]
        first_quart = get_minus_one_and_half_range(this_table['last_price'])
        quart_dict[i].append(first_quart)
                    
print(quart_dict) # Выведем словарь на экран
# Out:
# {1: [3133401.5, 1272500.0, 1726250.0, 1633625.0], 2: [810803.0, 0, 274577.0, 424250.0], 3: [304809.0, 0, 0, 0], 4: [0, 0, 0, 0]}

# %%
# Пишем функцию одной строки для замены пропусков в Санкт-Петербурге для 1, 2, 3 и 4-х комнатных квартир
# в столбце 'is_apartment'

def get_spb_apart_values(row):
    city = row['locality_name'] # Переменной city присвоим значение столбца 'locality_name'
    price = row['last_price'] # Переменной price присвоим значение столбца 'last_price'
    distance = row['city_centers_nearest'] # Переменной distanse присвоим значение удалённости от центра
    rooms = row['rooms'] # Переменной rooms присвоим число комнат в объекте недвижимости из столбца 'rooms'
    if city == 'Санкт-Петербург':  # Если значение столбца 'locality_name' равно строке 'Санкт-Петербург'
        for i in spb_rooms:  # Тогда запускаем цикл по значениям количества комнат в наиболее популярных предложениях
            if rooms == i: # Если значение в столбце 'rooms' равно значению переменной цикла
                for j in range(len(city_centers_q)):  # Тогда запускаем цикл по длине списка city_centers_q
                    if distance <= city_centers_q[j]: # Сравниваем значение удалённости от центра со значением 
                                                      # верхней границы группы по удалённости
                        if price < quart_dict[i][j]:  # Сравниваем стоимость объекта недвижимости со значением разности
                                                     # медианы и полутора межквартильных размахов, которое соответствует
                                                   # группе недвижимости по удалённости от центра и по количеству комнат
                            return True # И если значение меньше значения разности
                                        # медианы и полутора межквартильных размахов, тогда это апартаменты
                        else:
                            return False # Иначе объект недвижимости не является аппартаментами
    return row['is_apartment'] # Если ни одно из указанных условий неверно, то функция вернёт исходное значение

# %%
# Посчитаем доли пропусков до применения функции и после
apartment_skips_before = df['is_apartment'].isna().sum()
apartment_skips_part_before = apartment_skips_before / len(df)
print("Количество пропусков в столбце 'is_apartment' в исходных данных:", apartment_skips_before)
print("Что составляет {:.1%} от всех данных".format(apartment_skips_part_before))
# Out:
# Количество пропусков в столбце 'is_apartment' в исходных данных: 20890
# Что составляет 88.3% от всех данных

# %%
df['is_apartment'] = df.apply(get_spb_apart_values, axis=1) # Применяем функцию к столбцу 'is_apartment'

# %%
apartment_skips_after = df['is_apartment'].isna().sum()
apartment_skips_part_after = apartment_skips_after / len(df)
difference = apartment_skips_part_before - apartment_skips_part_after
print("Количество пропусков в столбце 'is_apartment' после применения функции:", apartment_skips_after)
print("Что составляет {:.1%} от всех данных".format(apartment_skips_part_after))
print("Мы избавились от {:.1%} пропусков в столбце 'is_apartment'".format(difference))
# Out:
# Количество пропусков в столбце 'is_apartment' после применения функции: 7586
# Что составляет 32.1% от всех данных
# Мы избавились от 56.3% пропусков в столбце 'is_apartment'

# %% [markdown]
# С пропусками для наиболее популярных предложений по числу комнат в Санкт-Петербурге разобрались. Оставшиеся 32.2% пропусков в столбце - это по-прежнему большая доля пропусков. Избавимся от пропусков по Ленинградской области.

# %%
# Создадим отдельную переменную для значений с указаниями типа жилплощади не в Санкт-Петербурге
lenobl_apart_false = df_apartment_false.query("locality_name != 'Санкт-Петербург'")

# %%
# Проверим, есть ли в нашей таблице пропуски в столбце 'city_centers_nearest'
lenobl_apart_false['city_centers_nearest'].isna().sum()

# 611 пропусков в столбце, где должны быть значения удалённости от центра. А сколько записей в нашей таблице?
# Out:
# 611

# %%
# Проверим длину таблицы
len(lenobl_apart_false)

# Примем как факт, что пропуски в столбце с удалённостью от центра города для объектов недвижимости 
# размещённых в Ленинградской области составляют более, чем 2/3 записей. Избавиться от такого количества 
# данных мы не можем: это негативно повлияет на точность наших рассчётов. Значит при рассчётах квартилей 
# по столбцу со стоимостью будем учитывать только количество комнат. Если в данных имеются выбросы, то 
# квартили очень помогут, так как они нечувствительны к выбросам.
# Out:
# 916

# %%
lenobl_apart_false['rooms'].value_counts() # Ознакомимся с наиболее популярными вариантами предложений

# В Ленобласти популярны предложения недвижимости 1-, 2- и 3-х комнатных квартир. Четырёхкомнатные квартиры 
# менее популярны. Так как их меньше 30 в данных таблицы lenobl_apart_false, мы не булем рассчитывать 
# по ним необходимые показатели и, соответственно, не будем заменять пропуски в значениях типа жилплощади
# в области для четырёхкомнатных квартир.
# Out:
# 1    348
# 2    340
# 3    191
# 4     25
# 5      7
# 0      4
# 6      1
# Name: rooms, dtype: int64

# %%
# Создадим список, который будет содержать самые популярные значения количества комнат у объектов недвижимости
# В Ленинградской области

lenobl_rooms = [1, 2, 3]

# %%
# Создадим словарь, в котором ключи будут соответствовать самым популярным значениям количетсва комнат у
# объектов недвижимости Ленобласти, а значения — значениям вычитания полутора межквартильных размахов
# из медианы по столбцу со стоимостью для объектов, разделённых по количеству комнат. После заполнения 
# словарь будет иметь такой вид:

# { 1-комнатные: медиана минус полтора межквартиальных размаха],
#   2-комнатные: медиана минус полтора межквартиальных размаха],
#   3-комнатные: медиана минус полтора межквартиальных размаха]
# }

lenobl_quart_dict = {}

for i in lenobl_rooms:
    that_table = lenobl_apart_false[lenobl_apart_false['rooms'] == i]
    lenobl_quart_dict[i] = get_minus_one_and_half_range(that_table['last_price'])
    
print(lenobl_quart_dict) # Выведем словарь на экран
# Out:
# {1: 910000.0, 2: 653370.0, 3: 1067500.0}

# %%
# Пишем функцию одной строки для замены пропусков в Ленобласти для 1, 2, 3-х комнатных квартир
# в столбце 'is_apartment'

def get_lenobl_apart_values(row):
    city = row['locality_name'] # Переменной city присвоим значение столбца 'locality_name'
    price = row['last_price'] # Переменной price присвоим значение столбца 'last_price'
    distance = row['city_centers_nearest'] # Переменной distanse присвоим значение удалённости от центра
    rooms = row['rooms'] # Переменной rooms присвоим число комнат в объекте недвижимости из столбца 'rooms'
    if city != 'Санкт-Петербург': # Если населённый пункт не Санкт-Петербург
        for i in lenobl_rooms:  # Тогда запускаем цикл по значениям количества комнат в наиболее популярных предложениях
            if rooms == i: # Если значение в столбце 'rooms' равно значению переменной цикла
                if price < lenobl_quart_dict[i]: # И если значение в столбце 'last_price' меньше значения разности
                                                 # медианы и полутора межквартильных размахов
                    return True # То это апартаменты
                else:
                    return False # Иначе — это не апартаменты
    return row['is_apartment'] # Если ни одно из указанных условий неверно, то функция вернёт исходное значение

# %%
# Снова посчитаем доли пропусков до применения функции и после
apartment_skips_before = df['is_apartment'].isna().sum()
apartment_skips_part_before = apartment_skips_before / len(df)
print("Количество пропусков в столбце 'is_apartment' в исходных данных:", apartment_skips_before)
print("Что составляет {:.1%} от всех данных".format(apartment_skips_part_before))
# Out:
# Количество пропусков в столбце 'is_apartment' в исходных данных: 7586
# Что составляет 32.1% от всех данных

# %%
df['is_apartment'] = df.apply(get_lenobl_apart_values, axis=1) # Применяем функцию к столбцу 'is_apartment'

# %%
apartment_skips_after = df['is_apartment'].isna().sum()
apartment_skips_part_after = apartment_skips_after / len(df)
difference = apartment_skips_part_before - apartment_skips_part_after
print("Количество пропусков в столбце 'is_apartment' после применения функции:", apartment_skips_after)
print("Что составляет {:.1%} от всех данных".format(apartment_skips_part_after))
print("Мы избавились от {:.1%} пропусков в столбце 'is_apartment'".format(difference))
# Out:
# Количество пропусков в столбце 'is_apartment' после применения функции: 884
# Что составляет 3.7% от всех данных
# Мы избавились от 28.3% пропусков в столбце 'is_apartment'

# %% [markdown]
# Мы заполнили ещё 28.3 % пропусков в столбце 'is_apartment'. Теперь процент пропусков в этом столбце составляет 3.7%.
# От оставшихся 3.7% можно смело избавиться и, наконец, привести значения столбца 'is_apartment' к типу bool.

# %%
df = df.dropna(subset=['is_apartment']) # Удалим строки с пропусками в столбце 'is_apartment'
df['is_apartment'].isna().sum() # Убедимся, что теперь пропусков нет
# Out:
# 0

# %%
df['is_apartment'] = df['is_apartment'].astype('bool') # Привели значения столбца 'is_apartment' к типу 'bool'

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера 💡</h1>
#
# А ты прям заморочился с этим столбцом) Хотя он нам не пригодится в далтнейшем анализе 😉. На само деле можно сделать предположение, что если квартира является аппартанентами, хозяин точно не пропустит этот признак при создании объявления, т.к. это важный фактр. А если же квартира не считается аппартаментами, то на этот фактор могут попросту не обратить внимания)
# </div>

# %%
df['last_price'] = df['last_price'].astype('int') # Привели значения столбца 'last_price' к типу 'int'

# %%
df['floors_total'].isna().sum() # Оценим число пропусков в столбце 'floors_total'
# Out:
# 78

# %%
df = df.dropna(subset=['floors_total']) # Удалим строки с пропусками в столбце 'floors_total', их не много
df['is_apartment'].isna().sum() # Убедимся, что теперь пропусков нет
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Согласен с этим решением)
# </div>

# %%
df['floors_total'] = df['floors_total'].astype('int') # Привели значения столбца 'floors_total' к типу 'int'

# %%
# Приведём столбец 'first_day_exposition' к типу даты и округлим дату до дня методом dt.floor() (к меньшему значению)
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S').dt.floor('1D')

# %%
# Сохраним в отдельной переменной таблицу с пропусками в строках столбца 'days_exposition'
days_exp_nan = df[df['days_exposition'].isna()]

# %%
# Объявим переменную last_date, в которой сохраним дату последней публикации объявления в базе недвижимости.

last_date = df[df['first_day_exposition'] == df['first_day_exposition'].max()]['first_day_exposition'].reset_index().loc[0, 'first_day_exposition']
type(last_date) # Убедились, что значение переменной имеет нужный нам тип
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['days_exposition'] = df['days_exposition'].fillna('NaN') # Заменим пропуски на строку 'NaN', чтобы к такой строке было
# проще обратиться в функции

# %%
# Создадим функцию одной строки, которая заменит значения столбца 'days_exposition', равные строке 'NaN' на количество дней,
# Которое прошло с даты публикации до даты в переменной last_date. 

def get_value_for_days_exp(row):
    if row['days_exposition'] == 'NaN':
        new_value = last_date - row['first_day_exposition']
        new_value = str(new_value)
        new_value = new_value.split(' ')[0]
        return int(new_value)
    return row['days_exposition']

# %%
# Применили функцию одной строки к столбцу 'days_exposition'

df['days_exposition'] = df.apply(get_value_for_days_exp, axis=1)

# %%
df['days_exposition'] = df['days_exposition'].astype('int') # Привели значения столбца 'days_exposition' к типу 'int'

# %%
df['days_exposition'].isna().sum() # Убедились, что в столбце 'days_exposition' больше нет пропусков
# Out:
# 0

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Логика правильная. Но нужно учитывать, что датасет выгружался не сегодня. Соответственно, лучше найти крайнюю дату публикации объявления и на ее снове посчитать сколько времени находится в активном статусе</div>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍 V2</h1>
#
# Молодец, что поправил)
# </div>

# %%
# В столбце 'rooms' у нас присутствуют значения равные числу 0, но такое значение для количества комнат нелогично.
# Проверим число строк с таким значением

df['rooms'].value_counts()
# Out:
# 1    7986
# 2    7881
# 3    5764
# 4     991
# 5      49
# 0       6
# 6       6
# 7       4
# 9       1
# Name: rooms, dtype: int64

# %%
# Таких строк 6, можем удалить их.

df = df[df['rooms'] != 0]
df['rooms'].value_counts() # Убедимся, что числа 0 больше нет среди значений столбца 'rooms'
# Out:
# 1    7986
# 2    7881
# 3    5764
# 4     991
# 5      49
# 6       6
# 7       4
# 9       1
# Name: rooms, dtype: int64

# %%
df.isna().sum() # Посмотрим на пропуски теперь
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           8745
# floors_total                0
# living_area              1780
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             1943
# balcony                     0
# locality_name               0
# airports_nearest         5265
# city_centers_nearest     5243
# parks_around_3000        5242
# parks_nearest           15003
# ponds_around_3000        5242
# ponds_nearest           14039
# days_exposition             0
# dtype: int64

# %%
# Теперь на основе данных, в которых указаны жилая площадь и площадь кухни рассчитаем медианное значение доли от общей площади
# (пропусков в значениях общей площади в наших данных нет) и заменим пропуски в значениях жилой площади и площади кухни,
# умножив общую площадь на соответствующие доли.

df_for_calc = df.dropna(subset=['living_area', 'kitchen_area'])
living_area_part = (df_for_calc['living_area'] / df_for_calc['total_area']).median()
kitchen_area_part = (df_for_calc['kitchen_area'] / df_for_calc['total_area']).median()

print("Медианное значение доли жилой площади от общей площади квартиры составляет {:.1%}".format(living_area_part))
print("Медианное значение доли кухни от общей площади квартиры составляет {:.1%}".format(kitchen_area_part))
# Out:
# Медианное значение доли жилой площади от общей площади квартиры составляет 56.4%
# Медианное значение доли кухни от общей площади квартиры составляет 17.4%

# %%
# Чтобы проще было обращаться к значениям пропусков из тел функций, заменим пропуски в столбцах на строки 'NaN'

df['living_area'] = df['living_area'].fillna('NaN')
df['kitchen_area'] = df['kitchen_area'].fillna('NaN')

# %%
# Напишем функцию одной строки для замены пропусков в столбце 'living_area'

def get_living_area_value(row):
    if row['living_area'] == 'NaN':
        new_value = round(row['total_area'] * living_area_part, 1) # Округляем значение до одного знака после запятой
        return new_value
    return row['living_area']

# %%
len(df[df['living_area'] == 'NaN']) # Проверим число строк в столбце 'living_area' в значении строк 'NaN' до
# Out:
# 1780

# %%
df['living_area'] = df.apply(get_living_area_value, axis=1) # Применяем функцию

# %%
len(df[df['living_area'] == 'NaN']) # Проверим число строк в столбце 'living_area' в значении строк 'NaN' после
# Out:
# 0

# %%
# Напишем функцию одной строки для замены пропусков в столбце 'kitchen_area'
def get_kitchen_area_value(row):
    if row['kitchen_area'] == 'NaN':
        new_value = round(row['total_area'] * kitchen_area_part, 1)
        return new_value
    return row['kitchen_area']

# %%
len(df[df['kitchen_area'] == 'NaN']) # Проверим число строк в столбце 'kitchen_area' в значении строк 'NaN' до
# Out:
# 1943

# %%
df['kitchen_area'] = df.apply(get_kitchen_area_value, axis=1) # Применяем функцию

# %%
len(df[df['kitchen_area'] == 'NaN']) # Проверим число строк в столбце 'kitchen_area' в значении строк 'NaN' после
# Out:
# 0

# %% [markdown]
# Теперь обратимся к значениям столбца 'ceiling_height': имеем и пропуски и выбросы, например, есть значения потолка равные одному метру. Посмотрим на распределение значений.

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Молодец, отлично разобрался с этими двумя столбцами
# </div>

# %%
df.plot(kind='hist', y='ceiling_height', bins=5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Есть и выбросы значений в 100 метров высоты потолка. Используем метод describe() чтобы подробнее взглянуть
# на данные

df['ceiling_height'].describe()
# Out:
# count    13937.000000
# mean         2.759605
# std          1.265421
# min          1.000000
# 25%          2.500000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
# Теперь, когда мы видим значения квартилей, взглянем на ту же гистограмму, но уже в других масштабах
df.plot(kind='hist', y='ceiling_height', bins=15, range=(2, 5), figsize=(12,5))
df.plot(kind='hist', y='ceiling_height', bins=15, range=(2.3, 4), figsize=(12,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
median_ceiling_height = df['ceiling_height'].median() # Сохранили медиану в переменной

# %%
# Заменим пустые значения столбца на медиану

df['ceiling_height'] = df['ceiling_height'].fillna(median_ceiling_height)

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Тоже отличное решение)
# </div>

# %%
normin = round(2.65 - (2.8 - 2.5) * 1.5, 1)
normax = round(2.65 + (2.8 - 2.5) * 1.5, 1)

# %%
print("Минимальное допустимое значение высоты потолка:", normin)
print("Максимальное допустимое значение высоты потолка:", normax)
# Out:
# Минимальное допустимое значение высоты потолка: 2.2
# Максимальное допустимое значение высоты потолка: 3.1

# %%
len(df.query('ceiling_height < @normin or ceiling_height > @normax')) # Считаем число выборосов
# Out:
# 1022

# %%
df = df.query('ceiling_height >= @normin and ceiling_height <= @normax') # Перезаписываем таблицу, избавляемся от выбросов

# %%
df.plot(kind='hist', y='ceiling_height', bins=10, figsize=(12,5)) # Смотрим на данные столбца без выбросов
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.isna().sum() # Оценили актуальное число пропусков в таблице
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5209
# city_centers_nearest     5190
# parks_around_3000        5189
# parks_nearest           14677
# ponds_around_3000        5189
# ponds_nearest           13657
# days_exposition             0
# dtype: int64

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
# Посчитаем и добавим в таблицу цену квадратного метра

df['square_meter_price'] = round(df['last_price'] / df['total_area'], 1)

df.head(5)
# Out:
# /tmp/ipykernel_84/3612957147.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['square_meter_price'] = round(df['last_price'] / df['total_area'], 1)
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# ...

# %%
# Создадим столбцы, которые будет содержать информацию о дне недели, месяце и годе публикации объявления.

# Чтобы получить корректный номер дня недели, будем прибавлять число 1 к значению его индекса 
from datetime import datetime

def create_weekday(row):
    weekday_index = datetime.weekday(row['first_day_exposition'])
    weekday = weekday_index + 1
    return weekday

def create_month(row):
    str_date = str(row['first_day_exposition'])
    month = str_date.split('-')[1]
    return month

def create_year(row):
    str_date = str(row['first_day_exposition'])
    year = str_date.split('-')[0]
    return year

# %%
df['weekday'] = df.apply(create_weekday, axis=1)
df['month'] = df.apply(create_month, axis=1)
df['year'] = df.apply(create_year, axis=1)


df.head() # Убедимся, что столбцы добавлены
# Out:
# /tmp/ipykernel_84/23792968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekday'] = df.apply(create_weekday, axis=1)
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# ...

# %%
# Добавим столбец с типом этажа квартиры; варианты — первый, последний, другой; Напишем функцию

def create_floor_type(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1: # если значение этажа равно единице (даже если это одноэтажный дом)
        return 'первый' # то этаж первый
    if floor == floors_total: # если значение этажа равно количеству этажей (кроме случая, когда первый этаж в одноэтажном доме)
        return 'последний' # то этаж последний
    return 'другой' # иначе этаж другой

# %%
df['floor_type'] = df.apply(create_floor_type, axis=1)
df.head() # Убедимся, что столбец добавлен

# В этом месте иногда появляется Warning. В целом он не мешает работе. Не совсем понятна природа происхождения
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         89.7      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    parks_around_3000  parks_nearest  ponds_around_3000  ponds_nearest  \
# ...

# %%
# Создадим столбец для значений соотношения жилой площади к общей площади

df['living_to_total_area'] = round(df['living_area'] / df['total_area'], 2)

# Создадим столбец для значений соотношения площади кухни к общей площади
df['kitchen_to_total_area'] = round(df['kitchen_area'] / df['total_area'], 2)

df.head() # Убедимся, что столбцы появились
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         89.7      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  square_meter_price  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Отлично, теперь данные готовы к анализу)
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Изучим следующие параметры:  площадь, цена, число комнат, высота потолков. Также построим гистограммы для каждого параметра.

# %%
# Изучим площадь и построим гистограмму по столбцу 'total_area'

df.plot(kind='hist', y='total_area', figsize=(12, 5), bins=15, title='total area distribution')
# Out:
# <AxesSubplot:title={'center':'total area distribution'}, ylabel='Frequency'>

# %% [markdown]
# На гистограмме видно, что большая часть значений находится в диапазоне до 200 квадратных метров. Имеются выбросы, значения которых стремятся к 500 квадратным метрам. Изучим данные с помощью метода describe() и построим гистограмму в более подходящем для исследования масштабе.

# %%
df['total_area'].describe()
# Out:
# count    21660.00000
# mean        56.15283
# std         25.02591
# min         12.00000
# 25%         39.80000
# 50%         50.10000
# 75%         66.00000
# max        494.10000
# Name: total_area, dtype: float64

# %% [markdown]
# Медианное значение площади составляет 49 квадратных метров. Половина данных лежит в диапазоне от 39 до 63 квадтраных метров. Среднее значение составляет 54.3 — это обусловлено наличием выбросов. Минимальное значение в наших данных составляет 12, а максимальное — 470 квадратных метров. Изучим данные в масштабе.

# %%
df.plot(kind='hist', y='total_area', figsize=(12, 5), bins=10, range=(20, 150), title='total area distribution')
# Out:
# <AxesSubplot:title={'center':'total area distribution'}, ylabel='Frequency'>

# %% [markdown]
# Распределение такой гистограммы напоминает распределение Пуассона и имеет пик в районе медианного значения, после медианного значения график идёт на спад, частота с увеличением метража объектов недвижимости затухает.

# %%
# Изучим цены и построим гистограмму по столбцу 'last_price'

df.plot(kind='hist', y='last_price', figsize=(12, 5), bins=10, title='last price distribution')
# Out:
# <AxesSubplot:title={'center':'last price distribution'}, ylabel='Frequency'>

# %%
df['last_price'].describe()
# Out:
# count    2.166000e+04
# mean     5.711100e+06
# std      6.079711e+06
# min      1.219000e+04
# 25%      3.390000e+06
# 50%      4.500000e+06
# 75%      6.300000e+06
# max      4.013000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Столбец 'last_price' содержит слишком большие значения, из-за чего читать гистограмму и результат вызова метода describe() с основными характеристиками столбца становится очень тяжело. Значения столбца 'last_price' будем считать в миллионах, для этого разделим значения столбца на миллион.
#
# Это изменение не повлечёт изменения в столбце 'square_meter_price', поэтому умножать значения этого столбца на миллион мы не будем.

# %%
df['last_price'] = round(df['last_price'] / 1000000, 3)
df.head() # Оценили таблицу после изменений в значении столбца 'last_price'
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0           2019-03-07      3
# 1             7       3.350        40.4           2018-12-04      1
# 2            10       5.196        56.0           2015-08-20      2
# 3             0      64.900       159.0           2015-07-24      3
# 4             2      10.000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         89.7      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  square_meter_price  \
# ...

# %%
df.plot(kind='hist', y='last_price', figsize=(12, 5), bins=10, title='last price distribution')
# Out:
# <AxesSubplot:title={'center':'last price distribution'}, ylabel='Frequency'>

# %% [markdown]
# Теперь не сложно заметить, что основной ценовой диапазон объектов недвижимости находится до 50 миллионов. В данных имеются выбросы, значения которых достигают 400 миллионов. Чтобы разобраться лучше, используем метод describe() и масштабируем гистограмму.

# %%
df['last_price'].describe()
# Out:
# count    21660.000000
# mean         5.711100
# std          6.079711
# min          0.012000
# 25%          3.390000
# 50%          4.500000
# 75%          6.300000
# max        401.300000
# Name: last_price, dtype: float64

# %% [markdown]
# Максимальное значение не только достигает, но даже превосходит 400 миллионов — 401,3 млн стоит самый дорогой объект недвижимости в наших данных. Минимальное значение составляет 12 тысяч. 50% наблюдений расположены в диапазоне от 3,3 миллионов до 5,95. Построим гистограмму в новом масштабе

# %%
df.plot(kind='hist', y='last_price', figsize=(12, 5), bins=15, range=(0, 30), title='last price distribution')
# Out:
# <AxesSubplot:title={'center':'last price distribution'}, ylabel='Frequency'>

# %% [markdown]
# Такое распределение больше напоминает нормальное, чем распределение с площадью объектов недвижимости. Мы видим, что максимальная частота находится в районе медианного значения, а объекты, чья стоимость находится в диапазонах от 0 до 2 миллионов и от 8 до 10 можно встретить с примерно одинаковой частотой. У распределения длинный хвост в сторону увеличения стоимость объектов недвижимости.

# %%
# Изучим число комнат и построим гистограмму по столбцу 'rooms'
df.plot(kind='hist', y='rooms', figsize=(12, 5), bins=10, title='rooms distribution')
# Out:
# <AxesSubplot:title={'center':'rooms distribution'}, ylabel='Frequency'>

# %% [markdown]
# Здесь не потребуется масштабирование: всё и так предельно ясно — наиболее популярным вариантов являются однокомнатные объекты недвижимости, затем с увеличением числа комнат частота таких объектов на рынке недвижимости снижается. Распределение Пуассона. Посмотрим на результаты, которые вернёт метод describe()

# %%
df['rooms'].describe()
# Out:
# count    21660.000000
# mean         1.964266
# std          0.880934
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          9.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Здесь можно заметить, что первый квартиль (и минимальное значение) соответствует однокомнатным квартирам, второй — двухкомнатным, а третий — трёхкомнатным. Максимальное число комнат в наших данных — 7.

# %%
# Изучим высоту потолков и построим гистограмму по столбцу 'ceiling_height'
df.plot(kind='hist', y='ceiling_height', figsize=(12, 5), bins=12, title='ceiling height distribution')
# Out:
# <AxesSubplot:title={'center':'ceiling height distribution'}, ylabel='Frequency'>

# %% [markdown]
# Так как мы удаляли выбросы из этого столбца, то помним, как распределены в нём значения после удаления выбросов: от 2.2 метров до 3.1. Пик гистограммы соответствует медианному значению. На гистограмме видно, что высота потолков от 2.8 до примерно 2.95 метров встречается реже, чем от 2.95 до 3.05.

# %%
# Теперь изучим время продажи квартиры. Построим гистограмму по столбцу 'days_exposition'.

df.plot(kind='hist', y='days_exposition', figsize=(12, 5), bins=10, title='days exposition distribution')
# Out:
# <AxesSubplot:title={'center':'days exposition distribution'}, ylabel='Frequency'>

# %% [markdown]
# На гистограмме видим распределение, напоминающее распределение Пуассона: в основном чем больше значение, тем реже оно встречается. Значения распределены от нуля дней до примерно 1700. Изучим данные с помощью метода describe(), чтобы построить гистограмму в более подходящем масштабе.

# %%
df['days_exposition'].describe()
# Out:
# count    21660.000000
# mean       179.494275
# std        226.691623
# min          0.000000
# 25%         42.000000
# 50%         91.000000
# 75%        226.000000
# max       1618.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# На основе значений, которые расположились в межквартильном размахе, мы можем утверждать, что обычно время продажи квартиры занимает от 42 до 226 дней, то есть от полутора до семи с половиной месяцев. При этом медиана в 91 день сильно отклоняется от среднего значения в 179 дней, что говорит о наличии выбросов в данных: мы видим, что максимальное значение составляет 1618 дней.
# И минимальное и максимальное значения вполне могут быть правдоподобными. На гистограмме в новом масштабе рассмотрим распределение значений от 0 до 500.

# %%
df.plot(kind='hist', y='days_exposition', figsize=(12, 5), bins=15, range=(0, 500), title='days exposition distribution')
# Out:
# <AxesSubplot:title={'center':'days exposition distribution'}, ylabel='Frequency'>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Отличные гистограммы ,молодец!
# </div>

# %% [markdown]
# На такой гистограмме ярко выраженный пик в районе значения первого квартиля, что говорит о том, что действительно полтора месяца это очень популярное значение дней, прошедших от публикации объявления до продажи объекта недвижимости. Распределение ещё больше стало напоминать распределение Пуассона. Оно плавно угасает от значения первого квартиля к значению 500 дней, которое мы выбрали в качестве границы масштаба.
#
# Можно считать, что продажи прошли быстро, если количество дней, прошедших с публикации объявления меньше значения медианы (118 дней) и необычно долго, если значение больше значения суммы медианы и полутора межквартильных размаха (больше 500 дней).
#
# Пункт: Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.
# В общем то, мы масштабировали гистограмму в самых популярных значениях и описали обнаруженные особенности :)
# Или имеется в виду просто удалить редкие выбивающиеся значения из столбцов таблицы на этом этапе?

# %% [markdown]
# Изучим, какие факторы больше всего влияют на стоимость квартиры. Выясним, зависит ли цена от площади, числа комнат, удалённости от центра, типа этажа (первый, последний, другой), а также зависимость от даты размещения: дня недели, месяца и года.

# %%
# Прежде, чем строить диаграмму рассеивания, удалим очень cильные выбросы из значений столбца last_price
# Мы помним, что основные значения цен расположены в диапазоне примерно до 60 миллионов

df_for_calc = df.query('last_price <= 60')

# %%
# Построим диаграмму рассеивания. Зависимую переменную (стоимость объекта недвижимости) разместим на оси y. 
# Независимую (площадь объекта недвижимости) — на оси x.

df_for_calc.plot(x='total_area', y='last_price', kind='scatter', alpha=0.2, figsize=(12, 5), title='price relation to area')
# Out:
# <AxesSubplot:title={'center':'price relation to area'}, xlabel='total_area', ylabel='last_price'>

# %%
# Рассчитаем коэффициент корреляции Пирсона
df_for_calc['last_price'].corr(df_for_calc['total_area'])
# Out:
# 0.7547828958937421

# %% [markdown]
# Значение коэффициента корреляции 0.75 говорит о наличии связи между ценой объекта недвижимости и его площадью. Чем больше площадь объекта недвижимости, тем, соответственно, больше стоимость объекта.

# %%
# Построим диаграмму рассеивания. Зависимую переменную (стоимость объекта недвижимости) разместим на оси y. 
# Независимую (число комнат) — на оси x.

df_for_calc.plot(x='rooms', y='last_price', kind='scatter', alpha=0.2, figsize=(12, 5), title='price relation to rooms')
# Out:
# <AxesSubplot:title={'center':'price relation to rooms'}, xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# Поскольку столбец со значениями количества комнат содержит дискретные значения, такая диаграмма рассеивания больше напоминает барчарт. Но и в таком виде можно сделать вывод: например, сказать, что взаимосвязь с положительной корреляцией прослеживается для объектов недвижимости, которые имеют от одной до четырёх комнат. Более верным решением будет действительно построить барчарт на основе данных из сводной таблицы, с помощью которой рассчитаем медианное значение цены для объектов недвижимости с разным числом комнат.

# %%
price_to_rooms = df_for_calc.pivot_table(index='rooms', values='last_price', aggfunc='median')
price_to_rooms.columns = ['median_price']
price_to_rooms['rooms'] = price_to_rooms.index
price_to_rooms = price_to_rooms.reset_index(drop=True)

price_to_rooms.plot(kind='bar', x='rooms', y='median_price', figsize=(12, 5), title='price relation to rooms')
# Out:
# <AxesSubplot:title={'center':'price relation to rooms'}, xlabel='rooms'>

# %% [markdown]
# Благодаря барчарту мы видим, что значение медианной стоимости объектов недвижимости в основном растёт по мере того, как растёт число комнат у объектов недвижимости. Можно утверждать, что число комнат влияет на цену объекта недвижимости.

# %%
# Построим диаграмму рассеивания. Зависимую переменную (стоимость объекта недвижимости) разместим на оси y. 
# Независимую (значение удалённости от центра) — на оси x.

df_for_calc.plot(x='city_centers_nearest', y='last_price', kind='scatter', alpha=0.2, figsize=(12, 5), title='price relation to distance')
# Out:
# <AxesSubplot:title={'center':'price relation to distance'}, xlabel='city_centers_nearest', ylabel='last_price'>

# %%
df_for_calc['last_price'].corr(df_for_calc['city_centers_nearest'])
# Out:
# -0.3060331256382425

# %% [markdown]
# Коэффициент корреляции принял отрицательное значение, но довольно малое для того, чтобы на основании него мы утверждали о существовании взаимосвязи между удалённостью объекта недвижимости от центра и его ценой. У малого значения есть причины: мы помним, что в наших данных есть пропуски в значениях столбца удалённости от центра у объектов недвижимости, расположенных в Ленинградской области. Таких пропусков не мало и, конечно, отсутствующие значения вносят своё влияние. По графику видно, что до значения удалённости от центра города в 20000 метров или 20 км (а именно на в таком радиусе от центра расположены окраины Санкт-Петербурга) отрицательная корреляция прослеживается, затем до значения 35000 метров (35 км) значения не меняются: можно утверждать, что цены на объекты недвижимости на этом участке находятся в одном диапазоне. Кстати, именно до 35 километров расположено большинство крупных населённых пунктов, представленных в наших данных. А дальше, как уже было сказно, много пропусков. Построим диграмму рассеивания до 20 км, чтобы рассчитать коэффициент корреляции более точно.

# %%
df_for_calc2 = df_for_calc.query('city_centers_nearest <= 20000')
df_for_calc2.plot(x='city_centers_nearest', y='last_price', kind='scatter', alpha=0.2, figsize=(12, 5), title='price relation to distance')
# Out:
# <AxesSubplot:title={'center':'price relation to distance'}, xlabel='city_centers_nearest', ylabel='last_price'>

# %%
df_for_calc2['last_price'].corr(df_for_calc2['city_centers_nearest'])
# Out:
# -0.3719019138274933

# %% [markdown]
# Значение коэффициента корреляции по модулю действительно увеличилось, однако, теперь мы видим, что своё влияние вносят объекты недвижимости, которые расположены в радиусе 6 километров от центра. По графику кажется, что до этого значения корреляция положительная, а после — становится отрицательной. Возможно, это связано с тем, что до 6 км не так много объектов недвижимости и каждый имеет сильно отличающееся от другого значения цены. Так или иначе говорить о том, что отрицательная корреляция просеживается в некоторых диапазонах, то есть зависимость всё таки существует, мы можем.

# %% [markdown]
# #Изучим зависимость цены от того, на каком этаже расположен объект недвижимости: на последнем, первом или другом.
# Переменная, которая хранится в значении столбца 'floor_type' является категориальной, поэтому строить диаграмму рассеивания и  считать коэффициент корреляции было бы не совсем верным решением. Воспользуемся сводной таблицей и графиком барплот.

# %%
price_to_floor = df_for_calc.pivot_table(index='floor_type', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
price_to_floor.columns = ['median_price']
price_to_floor['floor_type'] = price_to_floor.index
price_to_floor = price_to_floor.reset_index(drop=True)
display(price_to_floor)
# Out:
#    median_price floor_type
# 0           4.7     другой
# 1           4.1  последний
# 2           3.8     первый

# %%
price_to_floor.plot(kind='bar', x='floor_type', y='median_price', figsize=(12, 5), title='price relation to floor type')
# Out:
# <AxesSubplot:title={'center':'price relation to floor type'}, xlabel='floor_type'>

# %% [markdown]
# Сводная таблица и график барчарт имеют понятный и удобочитаемый вид. Объекты недвижимости не на первом и не на последнем этажах стоят дороже. Дешевле всего объекты недвижимости на первом этаже.

# %% [markdown]
# Изучим зависимость цены от того, в какой день недели было опубликовано объявление о продаже объекта недвижимости. День недели является категориальной переменной поэтому воспользуемся сводной таблицей, чтобы оценить медианное значение цены, на объекты недвижимости, выставленные на продажу в разные дни недели.

# %%
df_for_calc.pivot_table(index='weekday', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#          last_price
# weekday
# 2            4.6000
# 3            4.5500
# 1            4.5000
# 4            4.5000
# 7            4.4925
# 5            4.4890
# 6            4.4500

# %% [markdown]
# Видим отсутствие явных различий между днями недели, в которые были выставлены объекты недвижимости и их стоимостью. Объявления, размещённые во вторник имеют большее значение медианы: 4,6 миллиона. Объявления, выставленные в субботу — меньшее значение: 4.45. Различия невелики. На основе данных из сводной таблицы можем построить линейный график, чтобы увидеть как ведут себя медианные значения выставляемых объявлений о продаже недвижимости в течение недели.

# %%
weekday_distribution = df_for_calc.pivot_table(index='weekday', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
weekday_distribution['weekdays'] = weekday_distribution.index
weekday_distribution.sort_values('weekdays').plot(x='weekdays', y='last_price', figsize=(12, 5), grid=True, title='price relation to weekday')
# Out:
# <AxesSubplot:title={'center':'price relation to weekday'}, xlabel='weekdays'>

# %% [markdown]
# Линейный график демонстрирует пик медианного значения для объявлений, которые были выставлены во вторник.

# %% [markdown]
# Изучим зависимость цены от того, в какой месяц было опубликовано объявление о продаже объекта недвижимости. Месяц так же является категориальной переменной, поэтому мы будем строить сводную таблицу.

# %%
df_for_calc.pivot_table(index='month', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#        last_price
# month
# 04          4.680
# 11          4.599
# 09          4.550
# 12          4.550
# 01          4.500
# 02          4.500
# 03          4.500
# 08          4.500
# 10          4.500
# 07          4.450
# 05          4.430
# 06          4.250

# %% [markdown]
# О том, существует ли зависимость между месяцем публикации объявления и ценой объекта недвижимости также говорить сложно. Можем выделить апрель как месяц максимального медианного значения и такие месяцы как май, июнь и июль — в качестве месяцев с минимальными медианными значениями. На основе данных, полученных из сводной таблицы можем построить линейный график, чтобы более наглядно увидеть, как меняется медианное значение цены.

# %%
month_distribution = df_for_calc.pivot_table(index='month', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
month_distribution['months'] = month_distribution.index
month_distribution.sort_values('month').plot(x='months', y='last_price', figsize=(12, 5), grid=True, title='price relation to month')
# Out:
# <AxesSubplot:title={'center':'price relation to month'}, xlabel='months'>

# %% [markdown]
# На таком линейном графике видны абсолютный максимум медианного значения в апреле и абсолютный минимум в июне.

# %% [markdown]
# Изучим зависимость цены объекта недвижимости от года размещения. Год — это тоже категориальная переменная.

# %%
df_for_calc.pivot_table(index='year', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#       last_price
# year
# 2014       7.371
# 2015       5.000
# 2019       4.900
# 2018       4.500
# 2017       4.380
# 2016       4.370

# %% [markdown]
# Медианные значения стоимости объектов недвижимости за 2016 и 2017 годы — самые низкие. Взаимосвязь между стоимостью объекта недвижимости и годом, в который был выставлен этот объект так же отсутствует. Построим линейный график.

# %%
year_distribution = df_for_calc.pivot_table(index='year', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
year_distribution['years'] = year_distribution.index
year_distribution.sort_values('years').plot(x='years', y='last_price', figsize=(12, 5), grid=True, title='price relation to year')
# Out:
# <AxesSubplot:title={'center':'price relation to year'}, xlabel='years'>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Не нашел к чему придраться)
# </div>

# %%
# Выберем 10 населённых пунктов с наибольшим числом объявлений и посчитаем среднюю цену квадратного метра
popular_localities = df.pivot_table(index='locality_name', values='square_meter_price', aggfunc=['mean', 'count'])
popular_localities.columns = ['mean', 'count'] # Переименуем столбцы
# Отсортируем по количеству объявлений, выберем топ-10, после чего отсортируем по среднему значению стоимости
# квадратного метра в порядке убывания
popular_localities = popular_localities.sort_values('count', ascending=False).head(10).sort_values('mean', ascending=False)
popular_localities['locality'] = popular_localities.index # Значения индексов передадим отдельному столбцу
popular_localities = popular_localities.reset_index(drop=True) # Сбросим индексы
display(popular_localities)
# Out:
#             mean  count           locality
# 0  111808.041907  14148    Санкт-Петербург
# 1  102370.871976    339             Пушкин
# 2   92297.217668    283    деревня Кудрово
# 3   90613.497500    320  посёлок Парголово
# 4   85216.549184    490     посёлок Мурино
# 5   78334.685412    425     посёлок Шушары
# 6   75948.923718    312            Колпино
# 7   68793.157825    377         Всеволожск
# 8   68462.553177    299            Гатчина
# 9   57724.640476    210             Выборг

# %% [markdown]
# В топ-10 населённых пунктов по числу объявлений лидирует Санкт-Петербург. Также он лидирует по среднему показателю стоимости квадратного метра. На втором месте из топ-10 по числу объявление находится город Пушкин. Самый низкий показатель средней стоимости квадратного метра из этого топа — в городе Выборг. Построим для наглядности график барчарт.

# %%
popular_localities.plot(kind='bar', x='locality', y='mean', figsize=(12, 5), title="average values of square meter's price")
# Out:
# <AxesSubplot:title={'center':"average values of square meter's price"}, xlabel='locality'>

# %% [markdown]
# Выясним, какая область входит в центр Санкт-Петербурга. Для этого объявим отдельную таблицу, в которой будут находиться строки со значением 'Санкт-Петерубрг' в столбце 'locality_name'. Создадим для этой таблицы столбец, который будет хранить значения расстояния от центра до объектов недвижимости в километрах.

# %%
spb_df = df.query('locality_name == "Санкт-Петербург"')

# %%
spb_df['kilometers_to_center'] = spb_df['city_centers_nearest'] // 1000
# Out:
# /tmp/ipykernel_84/3698916995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spb_df['kilometers_to_center'] = spb_df['city_centers_nearest'] // 1000

# %%
# Чтобы привести значения столбца к целому типу, убедимся, что они не содержат пропусков.
spb_df['kilometers_to_center'].isna().sum()
# Out:
# 4

# %%
# Удалим пропуски и приведём значения столбца к целому типу
spb_df = spb_df.dropna(subset=['kilometers_to_center'])
spb_df['kilometers_to_center'] = spb_df['kilometers_to_center'].astype('int')

# %%
# Построим сводную таблицу, чтобы посчитать среднюю цену для каждого километра.

pivot_spb_df = spb_df.pivot_table(index='kilometers_to_center', values='last_price')
pivot_spb_df['kilometers_to_center'] = pivot_spb_df.index
pivot_spb_df = pivot_spb_df.reset_index(drop=True)

# %%
# На основе сводной таблицы построим линейный график, чтобы оценить, как меняется цена по удалённости от центра

pivot_spb_df.plot(x='kilometers_to_center', y='last_price', figsize=(12, 5), grid=True, title='price to distance')
# Out:
# <AxesSubplot:title={'center':'price to distance'}, xlabel='kilometers_to_center'>

# %% [markdown]
# Линейный график показывает, что резкое падение средней цены на объекты недвижимости начинается со значения 6 километров удалённости от центра. Будем считать центром Санкт-Петербурга область в радиусе 6 километров. Выделим сегмент квартир в центре. В отдельной таблице сохраним объекты недвижимости в центре Санкт-Петербурга b проанализируем такие параметры как площадь, цена, число комнат и высота потолков.

# %%
# Сохранили объекты недвижимости в центре Санкт-Петербурга в таблице center_spb_df
center_spb_df = spb_df.query('kilometers_to_center <= 6')

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Согласен с таким ограничением)
# </div>

# %%
# Построили гистограмму по значениям площади объектов недвижимости в центре Санкт-Петербурга в общем масштабе
center_spb_df.plot(kind='hist', y='total_area', bins=15, figsize=(12,5), title='total area distribution')
# Out:
# <AxesSubplot:title={'center':'total area distribution'}, ylabel='Frequency'>

# %%
# Изучили данные с помощью метода describe()
center_spb_df['total_area'].describe()
# Out:
# count    2229.000000
# mean       79.188502
# std        39.694459
# min        12.000000
# 25%        52.000000
# 50%        71.100000
# 75%        95.800000
# max       494.100000
# Name: total_area, dtype: float64

# %%
center_spb_df.plot(kind='hist', y='total_area', bins=15, figsize=(12,5), range=(0, 200), title='total area distribution')
# Out:
# <AxesSubplot:title={'center':'total area distribution'}, ylabel='Frequency'>

# %% [markdown]
# Распределение напоминает нормальное. Для объектов недвижимости в центре Санкт-Петербурга характерно медианное значение площади равное 71 квадратному метру. При этом первый квартиль равен 52 метрам, а третий — 95.
# Квартили для всех объектов недвижимости по Санкт-Петербургу и области выглядели так: 39, 50 и 66.
# Это говорит нам о том, что в центре Санкт-Петербурга площадь квартир значительно больше, чем по всей выборке в целом.

# %%
# Построим гистограмму по значениям цены объектов недвижимости в центре Санкт-Петербурга в общем масштабе
center_spb_df.plot(kind='hist', y='last_price', bins=15, figsize=(12,5), title='last price distribution')
# Out:
# <AxesSubplot:title={'center':'last price distribution'}, ylabel='Frequency'>

# %% [markdown]
# Основные значения стоимости объектов недвижимости в центре Санкт-Петербурга сосредоточены в диапазоне до 50 миллионов. Изучим данные столбца с помощью метода describe() и построим гистограмму в более подходящем масштабе.

# %%
center_spb_df['last_price'].describe()
# Out:
# count    2229.000000
# mean       12.006419
# std        14.603704
# min         1.600000
# 25%         6.300000
# 50%         8.400000
# 75%        12.511000
# max       401.300000
# Name: last_price, dtype: float64

# %% [markdown]
# Медианное значение стоимости объектов недвижимости в центре Санкт-Петербурга составляет 8.4 миллиона, первый и третий квартили равны значениям 6.3 и 12.5 миллионов соответственно. Против значений квартилей по всей выборке: 3.3, 4.5, 6.3 соответственно. Ещё раз: значение первого квартиля стоимости объектов недвижимости в центре Санкт-Петербурга  равно значению третьего квартиля стоимости объектов недвижимости на всей выборке. Это говорит о том, что стоимость объектов недвижимости в центре Санкт-Петербурга значительно выше: значения квартилей почти вдвое больше, чем значения квартилей рассчитанные для всех объектов недвижимости в наших данных.

# %%
center_spb_df.plot(kind='hist', y='last_price', bins=15, figsize=(12,5), range=(0, 50), title='last price distribution')
# Out:
# <AxesSubplot:title={'center':'last price distribution'}, ylabel='Frequency'>

# %% [markdown]
# Здесь распределение похоже на распределение Пуассона. Мы видим, что максимум находится в районе медианного значения цены.

# %%
# Построим гистограмму по значениям числа комнат объектов недвижимости в центре Санкт-Петербурга
center_spb_df.plot(kind='hist', y='rooms', bins=15, figsize=(12,5), title='rooms distribution')
# Out:
# <AxesSubplot:title={'center':'rooms distribution'}, ylabel='Frequency'>

# %% [markdown]
# Благодаря гистограмме мы видим, что в центре Санкт-Петербурга наиболее популярные варианты предложений объектов недвижимости имеют 2 и 3 комнаты, при чём количество предложений 2-х и 3-х комнатных квартир примерно одинаковое. Однокомнатные квартиры занимают третье место, а четырёхкомнатные следуют за ними с незначительным отрывом. Когда мы изучали распределение числа предложений по всем объектам недвижимости, мы получали в качестве самого популярного варианта однокомнатные квартиры и с ростом числа комнат у объекта недвижимости популярность снижалась.

# %%
# Построим гистограмму по значениям высоты потолков объектов недвижимости в центре Санкт-Петербурга
center_spb_df.plot(kind='hist', y='ceiling_height', bins=15, figsize=(12,5), title='ceiling height distribution')
# Out:
# <AxesSubplot:title={'center':'ceiling height distribution'}, ylabel='Frequency'>

# %% [markdown]
# Потолки высотой 2.65 метра по-прежнему самые популярные. Можно выделить второй по популярности высоты потолков вариант — потолки высотой в 3 метра. В прошлый раз, когда мы строили гистограмму по всем данным вторым по популярности высоты потолков вариантом у нас было значение 2.5 метра. Значит в центре Санкт-Петербурга в объектах недвижимости потолки выше.

# %% [markdown]
# Теперь выделим факторы, которые влияют на стоимость объекта недвижимости в центре Санкт-Петербурга. Изучим влияние числа комнат, типа этажа, удалённости от центра и даты размещения объявления.

# %%
# Прежде, чем строить графики по данным, также исключим выбросы из значений столбца 'last_price'
# и сохраним таблицу без выбросов в новой переменной.

center_spb_for_calc = center_spb_df.query('last_price <= 60')

# %%
# Создадим сводную таблицу и на основе её данных построим график барплот

price_to_rooms2 = center_spb_for_calc.pivot_table(index='rooms', values='last_price', aggfunc='median')
price_to_rooms2.columns = ['median_price']
price_to_rooms2['rooms'] = price_to_rooms2.index
price_to_rooms2 = price_to_rooms2.reset_index(drop=True)

price_to_rooms2.plot(kind='bar', x='rooms', y='median_price', figsize=(12, 5), title='price relation to rooms')
# Out:
# <AxesSubplot:title={'center':'price relation to rooms'}, xlabel='rooms'>

# %% [markdown]
# Также как и в случае с наблюдениями по всей базе недвижимости, можем отметить, что наблюдается рост медианного значения цены с ростом числа комнат.

# %%
# Для типа этажа построим сводную таблицу.

center_spb_for_calc.pivot_table(index='floor_type', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#             last_price
# floor_type
# другой           8.775
# последний        8.300
# первый           6.200

# %% [markdown]
# Как и в случае с наблюдениями по всей базе, можем отметить, что медианное значение цены объектов недвижимости в центре Санкт-Петербурга выше для этажа, который не является первым или последним и ниже — для первого этажа. Эти медианные значение почти вдвое выше, чем для наблюдений по всей базе.

# %%
center_spb_for_calc.plot(x='city_centers_nearest', y='last_price', kind='scatter', alpha=0.2, figsize=(12, 5), title='price relation to distance')
# Out:
# <AxesSubplot:title={'center':'price relation to distance'}, xlabel='city_centers_nearest', ylabel='last_price'>

# %%
center_spb_for_calc['last_price'].corr(center_spb_for_calc['city_centers_nearest'])
# Out:
# 0.040080141420298046

# %% [markdown]
# По диаграмме рассеивания можно сказать, что чем больше удалённость от центра, тем большим количеством объектов недвижимости представлены объявления о продаже, соответственно и больше разброс цен. Утверждать о наличии взаимосвязи мы не можем. Значение коэффициента корреляции 0.4 — что так же говорит о том, что взаимосвязи нет.

# %%
# Используем сводную таблицу, чтобы оценить медианное значение цены, на объекты недвижимости, выставленные
# на продажу в разные дни недели

center_spb_for_calc.pivot_table(index='weekday', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#          last_price
# weekday
# 1             8.600
# 7             8.589
# 3             8.500
# 5             8.400
# 2             8.300
# 6             8.010
# 4             7.971

# %% [markdown]
# Как и в случае с наблюдениями по всей базе недвижимости, видим отсутствие явных различий между днями недели, в которые были выставлены объекты недвижимости и их стоимостью. Здесь лидером по значению медианы является понедельние: 8,6 миллиона (значение лидера медианы по всей выборки было равно 4.6 миллионам и тогда это был вторник). Объявления, выставленные в четверг имеют наименьшее значение медианной стоимости — 7,9 миллионов (в прошлый раз аутсайдером была суббота со значением 4.45 миллионов). Как и в прошлый раз, мы можем утверждать, что различия невелики. На основе данных из сводной таблицы можем построить линейный график, чтобы увидеть как ведут себя медианные значения выставляемых объявлений о продаже недвижимости в течение недели.

# %%
weekday_distribution2 = center_spb_for_calc.pivot_table(index='weekday', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
weekday_distribution2['weekdays'] = weekday_distribution2.index
weekday_distribution2.sort_values('weekdays').plot(x='weekdays', y='last_price', figsize=(12, 5), grid=True, title='price relation to weekday')
# Out:
# <AxesSubplot:title={'center':'price relation to weekday'}, xlabel='weekdays'>

# %% [markdown]
# Линейный график медианных значений стоимости объектов недвижимости, расположенных в центре Санкт-Петербурга, выставленных в разные дни отличается от линейного графика медианных значений стоимости по всей базе недвижимости. Настоящий график более острый. Это говорит о том, что зависимость отсутствует полностью: каждый день не похож на предыдущий день недели.

# %%
# Попытаемся оценить зависимость между месяцем публикации объявления и ценой объекта недвижимости в центре СПБ.

center_spb_for_calc.pivot_table(index='month', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#        last_price
# month
# 11         8.7500
# 08         8.5945
# 01         8.5000
# 02         8.5000
# 03         8.5000
# 09         8.5000
# 07         8.4950
# 10         8.3135
# 04         8.2000
# 05         7.9040
# 06         7.8000
# 12         7.7000

# %% [markdown]
# Мы помним, что в сводной таблице, построенной по всей базе лидером по значению медианной стоимости был месяц апрель. Сейчас апрель близок к аутсайдерам по своему значению медианы. Вместе с маем, июнем и декабрём он занимает последние строки «рейтинга популярных месяцев». Лидером является ноябрь, на втором месте август, а на третьем — январь. Есть подозрение, что линейный график получится более ломанным, чем в случае с наблюдениями по всей базе недвижимости. Проверим, подтвердятся ли подозрения.

# %%
month_distribution2 = center_spb_for_calc.pivot_table(index='month', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
month_distribution2['months'] = month_distribution2.index
month_distribution2.sort_values('month').plot(x='months', y='last_price', figsize=(12, 5), grid=True, title='price relation to month')
# Out:
# <AxesSubplot:title={'center':'price relation to month'}, xlabel='months'>

# %% [markdown]
# На этом линейном графике видно, что первые три месяца года отличаются стабильностью, после которой следует падение медианного значения цены с последующим ростом после июня месяца. Видно, что направление графика часто меняется. Можно утверждать о том, что зависимости цены от месяца нет, но июнь стабильно является месяцем с низким значением медианы как в наблюдениях по всей базе недвижимости, так и в наблюдениях по объектам недвижимости, расположенным в центре Санкт-Петербурга.

# %%
# Попробуем увидеть зависимость между годом, в котором был выставлен на продажу объект недвижимости в центре
# Санкт-Петербурга и его ценой.

center_spb_for_calc.pivot_table(index='year', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
# Out:
#       last_price
# year
# 2014      16.200
# 2019       8.945
# 2015       8.600
# 2016       8.340
# 2017       8.200
# 2018       8.100

# %% [markdown]
# Как и в случае с наблюдениями по всей базе недвижимости, 2014-й год — абсолютный лидер по показателю медианного значения стоимости объектов недвижимости. Вероятно, дело в кризисе, который произошёл в тот год :) Посмотрим, как ведут себя эти данные на линейном графике.

# %%
year_distribution2 = center_spb_for_calc.pivot_table(index='year', values='last_price', aggfunc='median').sort_values('last_price', ascending=False)
year_distribution2['years'] = year_distribution2.index
year_distribution2.sort_values('years').plot(x='years', y='last_price', figsize=(12, 5), grid=True, title='price relation to year')
# Out:
# <AxesSubplot:title={'center':'price relation to year'}, xlabel='years'>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Ну и снова не к чему придраться)
# </div>

# %% [markdown]
# # 5 Общий вывод

# %% [markdown]
# В результате проведённого исследования были изучены распределения значений площади, цены, числа комнат и высоты потолков объектов недвижимости по всей базе недвижимости и отдельно по объектам недвижимости, расположенным в центре Санкт-Петербурга.

# %%
all_data_area = df['total_area'].describe()[4:7]
spb_center_area = center_spb_df['total_area'].describe()[4:7]

ax = all_data_area.plot(legend=True,
                        linewidth=5,
                       label='All data')

spb_center_area.plot(ax=ax, 
                figsize=(15, 5),
                linewidth=5,
                grid=True,
                label = "St.Petersburg's center",
                legend=True,
                xlabel='quartiles',
                ylabel='area in square meters',
                title='difference between main parameters of area values')
# Out:
# <AxesSubplot:title={'center':'difference between main parameters of area values'}, xlabel='quartiles', ylabel='area in square meters'>

# %% [markdown]
# Значения площади квартир в центре Санкт-Петербурга выше, чем значения по всей базе недвижимости. На графике можно увидеть сравнение значений первого, второго и третьего квартилей. Можно заметить, что от первого к третьему квартилю увеличивается разрыв в значениях. Медианное значение объекта недвижимости по всей базе равно 50 квадратным метрам, тогда как по объектам недвижимости в центре Санкт-Петербурга — превышает значение в 70 квадратных метров.

# %%
all_data_price = df['last_price'].describe()[4:7]
spb_center_price = center_spb_df['last_price'].describe()[4:7]

ax = all_data_price.plot(legend=True,
                        linewidth=5,
                       label='All data')

spb_center_price.plot(ax=ax, 
                figsize=(15, 5),
                linewidth=5,
                grid=True,
                label = "St.Petersburg's center",
                legend=True,
                xlabel='quartiles',
                ylabel='price in millions',
                title='difference between main parameters of price values')
# Out:
# <AxesSubplot:title={'center':'difference between main parameters of price values'}, xlabel='quartiles', ylabel='price in millions'>

# %% [markdown]
# Значения цен в центре Санкт-Петербурга так же выше, чем значения цен по всей базе недвижимости. Медиана, рассчитанная по значениям объектов недвижимости центра Санкт-Петербурга превосходит медиану всей базы почти вдвое. Очевидно, что квартиры в центре дороже. Также как и в случае с площадью объектов недвижимости можем наблюдать увеличение разрыва между линиями графиков о первого квартиля к третьему.

# %% [markdown]
# Самыми популярными вариантами объектов недвижимости во всей базе являются однушки и по мере увеличения числа комнат количество объявлений уменьшается, тогда как в случае с центром Санкт-Петербурга наиболее популярные варианты это двух- и трёхкомнатные объекты недвижимости: они сильно популярнее, чем однокомнатные и четырёхкомнатные, между которыми, в свою очередь разрыв незначителен. Покажем это с помощью графиков пайчарт.

# %%
all_data_rooms = df.query('rooms <= 4').pivot_table(index='rooms', values='last_price', aggfunc='count')
all_data_rooms.columns = ['count']
all_data_rooms.plot(kind='pie', 
                    y='count', 
                    figsize=(8, 8), 
                    autopct='%.1f%%',
                    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
                    legend=False, 
                    title='All data parts of different room values', 
                    label='parts')
# Out:
# <AxesSubplot:title={'center':'All data parts of different room values'}, ylabel='parts'>

# %%
spb_center_rooms = center_spb_df.query('rooms <= 4').pivot_table(index='rooms', values='last_price', aggfunc='count')
spb_center_rooms.columns = ['count']
spb_center_rooms.plot(kind='pie', 
                      y='count', 
                      figsize=(8, 8), 
                      autopct='%.1f%%',
                      wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
                      legend=False, 
                      label='parts', 
                      title="St. Petersburg's parts of different room values")
# Out:
# <AxesSubplot:title={'center':"St. Petersburg's parts of different room values"}, ylabel='parts'>

# %% [markdown]
# Значения высоты потолков в центре Санкт-Петербурга так же выше, чем значения цен по всей базе недвижимости. Вторым по популярности вариантом высоты потолков во всей базе является значение 2.5 метра, тогда как в центре Санкт-Петербурга второй вариант — это 3 метра. Посмотрим, как отличаются квартили распределения с помощью линейных графиков.

# %%
all_data_ceiling_height = df['ceiling_height'].describe()[4:7]
spb_center_celing_height = center_spb_df['ceiling_height'].describe()[4:7]

ax = all_data_ceiling_height.plot(legend=True,
                        linewidth=5,
                       label='All data')

spb_center_celing_height.plot(ax=ax, 
                figsize=(15, 5),
                linewidth=5,
                grid=True,
                label = "St.Petersburg's center",
                legend=True,
                xlabel='quartiles',
                ylabel='area in square meters',
                title='difference between main parameters of area values')
# Out:
# <AxesSubplot:title={'center':'difference between main parameters of area values'}, xlabel='quartiles', ylabel='area in square meters'>

# %% [markdown]
# На графике видно, что медианные значения, рассчитанные по объектам всей базы недвижимости и по объектам в центре Санкт-Петербурга совпадают, первые квартили различаются незначительно (всего на пять сантиметров), тогда как основной разрыв виден на третьем квартиле. Это говорит о том, что в центре Санкт-Петербурга доля объектов недвижимости с потолками, чьи значения стремятся к значению в 3 метра примерно такая же, как и доля объектов по всей базе, чьи значения стремятся к значению в 2.7 метра. Потолки в центре Санкт-Петербурга выше.

# %% [markdown]
# Также в ходе исследования мы выяснили, что на стоимость объекта недвижимости влияет число комнат, при этом любопытным оказалось наблюдение, что медианное значение стоимости семикомнатной квартиры ниже, как по всем объектам наблюдений, так и по объектам недвижимости в центре Санкт-Петербурга. Отрицательная корреляция наблюдается лишь на некоторых участках, графика, если говорить о взаимосвязи цены и удалённости от центра. Это может быть обусловлено малым числом предложений (и, как следствие, большим разбросом цен) в непосредственной близости к центру Санкт-Петербурга, а также отсутствующими значениями удалённости от центра города для объектов недвижимости, расположенных в Ленинградской области. Также мы заметили, что в радиусе 15 километров от городской черты (или 35 километров от центра) стоимость объектов недвижимости практически не меняется — в этом радиусе расположены наиболее крупные населённые пункты Ленинградской области. Самым «дешёвым» этажом для объекта недвижимости является первый этаж, самыми дорогими этажами — ни первый и не последний и это неизменно как в наблюдениях по всей базе, так и для объектов в центре города. День недели, в который было выставлено объявление о продаже объекта недвижимости никак не влияет на стоимость. В месяцах можно увидеть закономерность, что летом объекты недвижимости стоят дешевле. В 2014-м году (вероятно, причиной тому кризис) стоимость недвижимости была сильно выше, при чём у объектов в центре Санкт-Петербурга она была выше более чем в 2 раза, чем в последующие годы. В наблюдениях по всем объектам недвижимости можно увидеть кратность в полтора раза между 2014-м и последующим годами.

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера 👍</h1>
#
# Отличный вывод. Очень полный и детальный)
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Общий комментарий о работе</h1>
#
# Отличная работа! Ты молодец) Видно, что неплохо разобрался с темой спринта. Есть немного замечаний, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Возможно их нужно будет скорректировать.
#
# Жду доработанную версию проекта)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Общий комментарий о работе V2</h1>
#
# Критических замечаний больше нет, значит проект можно принимать) Спасибо большое за проделанную работу, у тебя получился отличный проект!
#
# Желаю успехов тебе в дальнейшем обучении)
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [ ]  файлы изучены (выведены первые строки, метод `info()`)
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  посчитано и добавлено в таблицу: цена квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [ ]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [ ]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [ ]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [ ]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [ ]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [ ]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [ ]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [ ]  в каждом этапе есть выводы
# - [ ]  есть общий вывод
